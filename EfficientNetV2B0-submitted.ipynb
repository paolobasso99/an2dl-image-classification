# %% [markdown]
# # Image Classification challange AN2DL Politecnico di Milano 2022
# This is ..

# %% [markdown]
# ## Define the environment
# 1. **Colab**: the notebook must be in a folder where there is a folder called `data` and the `zip` file containing the training data inside (i.e. `data/training_dataset_homework1.zip`).
# 2. **Local**: extract the `zip` file containing the training data in `data/training_data_final`

# %%
IS_COLAB = True
COLAB_BASE_DIR = '/gdrive/MyDrive/colab/AN2DL1/'
USE_WHOLE_DATASET = True # if True do not perform validation and analysis, just train with all the data

# %% [markdown]
# ## Libraries import

# %%
import os
import enum
import json
from datetime import datetime
import random
from typing import Tuple, Callable, Dict, Optional, List

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Check device
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ### Seed

# %%
# Random seed for reproducibility
SEED = 42

random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ### Mount Google Drive (if using Colab)

# %%
if IS_COLAB:
    from google.colab import drive
    drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# ### Check folders

# %%
ROOT_DIR = os.getcwd()
DATA_DIR = 'data/training_data_final'

if IS_COLAB:
  if not os.path.exists('data'):
    # !mkdir 'data'
  if not os.path.isfile('data/training_dataset_homework1.zip'):
    zip_source = COLAB_BASE_DIR + 'data/training_dataset_homework1.zip'
    # !cp $zip_source 'data'
  if not os.path.exists(DATA_DIR):
    # !unzip 'data/training_dataset_homework1' -d 'data'
else:
  if not os.path.exists('data'):
    raise RuntimeError("data/training_data_final path not found.")
  if not os.path.exists(DATA_DIR):
    raise RuntimeError("please unzip data/training_dataset_homework1.zip")

# %% [markdown]
# ## Load datasets

# %% [markdown]
# Define datasets hyperparameters

# %%
VALIDATION_SPLIT = 0.2
BATCH_SIZE = 64

# %%
IMG_SIZE = (96, 96)
IMG_SHAPE = IMG_SIZE + (3,)
N_CLASSES = 8

if USE_WHOLE_DATASET:
  complete_ds = tf.keras.utils.image_dataset_from_directory(
      DATA_DIR,
      labels='inferred',
      label_mode='int',
      color_mode='rgb',
      batch_size=BATCH_SIZE,
      image_size=IMG_SIZE,
      shuffle=True,
      seed=SEED,
  )
else:
    train_ds = tf.keras.utils.image_dataset_from_directory(
        DATA_DIR,
        labels='inferred',
        label_mode='int',
        color_mode='rgb',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        shuffle=True,
        seed=SEED,
        validation_split=VALIDATION_SPLIT,
        subset = 'training'
    )

    val_ds = tf.keras.utils.image_dataset_from_directory(
        DATA_DIR,
        labels='inferred',
        label_mode='int',
        color_mode='rgb',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        shuffle=True,
        seed=SEED,
        validation_split=VALIDATION_SPLIT,
        subset = 'validation'
    )
# Out:
# Found 3542 files belonging to 8 classes.
# Found 3542 files belonging to 8 classes.
# Using 2834 files for training.
# Found 3542 files belonging to 8 classes.
# Using 708 files for validation.

# %% [markdown]
# Configure the dataset for performance, see the [Better performance with the tf.data API](https://www.tensorflow.org/guide/data_performance) guide:

# %%
AUTOTUNE = tf.data.AUTOTUNE

if USE_WHOLE_DATASET:
  complete_ds = complete_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
else:
  train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
  val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Preprocessing and Data Augmentation

# %%
data_augmentation_layer = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomContrast(0.1),
  #tf.keras.layers.RandomBrightness(0.01),
  tf.keras.layers.RandomZoom(0.1),
  tf.keras.layers.RandomTranslation(0.1, 0.1)
], name='data_augmentation')

for image, _ in train_ds.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation_layer(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %% [markdown]
# ## Base model

# %%
if USE_WHOLE_DATASET:
  BASE_MODEL_EPOCHS = 39

BASE_MODEL_LEARNING_RATE = 5e-3
BASE_MODEL_OPTIMIZER = tf.keras.optimizers.Adam(BASE_MODEL_LEARNING_RATE)
BASE_MODEL_LOSS = tf.keras.losses.SparseCategoricalCrossentropy()
BASE_MODEL_EARLY_STOPPING_PATIENCE = 10

# %%
base_model_supernet = tf.keras.applications.EfficientNetV2B0(
    input_shape=IMG_SHAPE,
    include_top=False,
    weights='imagenet'
)
base_model_supernet.trainable = False

# %%
base_model = tf.keras.Sequential([
    tf.keras.Input(shape=IMG_SHAPE, name="input"),
    data_augmentation_layer,
    #tf.keras.layers.Rescaling(1./127.5, offset=-1),
    base_model_supernet,
    #tf.keras.layers.GlobalAveragePooling2D(name="avg_pool"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1024, activation='relu', kernel_initializer=tf.keras.initializers.HeUniform(SEED)),
    tf.keras.layers.Dense(512, activation='relu', kernel_initializer=tf.keras.initializers.HeUniform(SEED)),
    tf.keras.layers.Dense(256, activation='relu', kernel_initializer=tf.keras.initializers.HeUniform(SEED)),
    tf.keras.layers.Dense(128, activation='relu', kernel_initializer=tf.keras.initializers.HeUniform(SEED)),
    tf.keras.layers.Dense(128, activation='relu', kernel_initializer=tf.keras.initializers.HeUniform(SEED)),
    tf.keras.layers.Dense(N_CLASSES, name='output', activation='softmax', kernel_initializer=tf.keras.initializers.GlorotUniform(SEED))
], name="base_model")

# %%
base_model.compile(
    optimizer=BASE_MODEL_OPTIMIZER,
    loss=BASE_MODEL_LOSS,
    metrics=['accuracy']
)
base_model.summary()
# Out:
# Model: "base_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data_augmentation (Sequenti  (None, 96, 96, 3)        0
#  al)
#
#  efficientnetv2-b0 (Function  (None, 3, 3, 1280)       5919312
#  al)
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1280)       5120
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 3, 3, 1280)        0
#
#  flatten_1 (Flatten)         (None, 11520)             0
#
#  dense_5 (Dense)             (None, 1024)              11797504
#
#  dense_6 (Dense)             (None, 512)               524800
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  output (Dense)              (None, 8)                 1032
#
# =================================================================
# Total params: 18,428,504
# Trainable params: 12,506,632
# Non-trainable params: 5,921,872
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
if USE_WHOLE_DATASET:
  base_model_history = base_model.fit(
    complete_ds,
    epochs=BASE_MODEL_EPOCHS
  )
else:
  # use early stopping
  base_model_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=BASE_MODEL_EARLY_STOPPING_PATIENCE, restore_best_weights=True)
  base_model_history = base_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks = [base_model_early_stopping],
  )
# Out:
# Epoch 1/39
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# 56/56 [==============================] - 47s 645ms/step - loss: 2.9487 - accuracy: 0.3303
# Epoch 2/39
# 56/56 [==============================] - 36s 639ms/step - loss: 1.3267 - accuracy: 0.5217
# Epoch 3/39
# 56/56 [==============================] - 36s 635ms/step - loss: 1.1539 - accuracy: 0.5889
# Epoch 4/39
# 56/56 [==============================] - 36s 637ms/step - loss: 1.1273 - accuracy: 0.6033
# Epoch 5/39
# 56/56 [==============================] - 37s 664ms/step - loss: 1.0822 - accuracy: 0.6251
# Epoch 6/39
# 56/56 [==============================] - 36s 637ms/step - loss: 1.0422 - accuracy: 0.6505
# Epoch 7/39
# 56/56 [==============================] - 36s 634ms/step - loss: 1.0207 - accuracy: 0.6575
# Epoch 8/39
# 56/56 [==============================] - 35s 630ms/step - loss: 0.9807 - accuracy: 0.6581
# Epoch 9/39
# 56/56 [==============================] - 36s 634ms/step - loss: 0.9468 - accuracy: 0.6776
# Epoch 10/39
# 56/56 [==============================] - 35s 633ms/step - loss: 0.9406 - accuracy: 0.6790
# Epoch 11/39
# 56/56 [==============================] - 36s 636ms/step - loss: 0.9112 - accuracy: 0.6835
# Epoch 12/39
# 56/56 [==============================] - 37s 662ms/step - loss: 0.9565 - accuracy: 0.6725
# Epoch 13/39
# 56/56 [==============================] - 36s 638ms/step - loss: 0.9016 - accuracy: 0.6894
# Epoch 14/39
# 56/56 [==============================] - 36s 637ms/step - loss: 0.9225 - accuracy: 0.6829
# Epoch 15/39
# 56/56 [==============================] - 36s 640ms/step - loss: 0.8728 - accuracy: 0.6993
# Epoch 16/39
# 56/56 [==============================] - 36s 637ms/step - loss: 0.8648 - accuracy: 0.7072
# Epoch 17/39
# 56/56 [==============================] - 36s 647ms/step - loss: 0.8471 - accuracy: 0.7086
# Epoch 18/39
# 56/56 [==============================] - 35s 631ms/step - loss: 0.8660 - accuracy: 0.7067
# Epoch 19/39
# 56/56 [==============================] - 37s 661ms/step - loss: 0.8286 - accuracy: 0.7165
# Epoch 20/39
# 56/56 [==============================] - 36s 633ms/step - loss: 0.8437 - accuracy: 0.7058
# Epoch 21/39
# 56/56 [==============================] - 35s 631ms/step - loss: 0.8198 - accuracy: 0.7196
# Epoch 22/39
# 56/56 [==============================] - 35s 625ms/step - loss: 0.8112 - accuracy: 0.7281
# Epoch 23/39
# 56/56 [==============================] - 35s 629ms/step - loss: 0.8181 - accuracy: 0.7222
# Epoch 24/39
# 56/56 [==============================] - 35s 627ms/step - loss: 0.7882 - accuracy: 0.7253
# Epoch 25/39
# 56/56 [==============================] - 35s 627ms/step - loss: 0.8012 - accuracy: 0.7264
# Epoch 26/39
# 56/56 [==============================] - 37s 663ms/step - loss: 0.7704 - accuracy: 0.7369
# Epoch 27/39
# 56/56 [==============================] - 36s 634ms/step - loss: 0.7899 - accuracy: 0.7185
# Epoch 28/39
# 56/56 [==============================] - 36s 644ms/step - loss: 0.8191 - accuracy: 0.7287
# Epoch 29/39
# 56/56 [==============================] - 36s 636ms/step - loss: 0.7640 - accuracy: 0.7338
# Epoch 30/39
# 56/56 [==============================] - 36s 644ms/step - loss: 0.8276 - accuracy: 0.7264
# Epoch 31/39
# 56/56 [==============================] - 36s 640ms/step - loss: 0.7796 - accuracy: 0.7431
# Epoch 32/39
# 56/56 [==============================] - 36s 637ms/step - loss: 0.7542 - accuracy: 0.7318
# Epoch 33/39
# 56/56 [==============================] - 36s 635ms/step - loss: 0.7321 - accuracy: 0.7544
# Epoch 34/39
# 56/56 [==============================] - 36s 637ms/step - loss: 0.7710 - accuracy: 0.7411
# Epoch 35/39
# 56/56 [==============================] - 35s 633ms/step - loss: 0.7481 - accuracy: 0.7428
# Epoch 36/39
# 56/56 [==============================] - 36s 641ms/step - loss: 0.7501 - accuracy: 0.7386
# Epoch 37/39
# 56/56 [==============================] - 36s 637ms/step - loss: 0.7736 - accuracy: 0.7357
# Epoch 38/39
# 56/56 [==============================] - 36s 638ms/step - loss: 0.7353 - accuracy: 0.7569
# Epoch 39/39
# 56/56 [==============================] - 37s 665ms/step - loss: 0.7188 - accuracy: 0.7575

# %% [markdown]
# ### Visualize performance

# %%
acc = base_model_history.history['accuracy']
if not USE_WHOLE_DATASET:
  val_acc = base_model_history.history['val_accuracy']

loss = base_model_history.history['loss']
if not USE_WHOLE_DATASET:
  val_loss = base_model_history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
if not USE_WHOLE_DATASET:
  plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([min(plt.ylim()),1])
if not USE_WHOLE_DATASET:
  plt.plot([base_model_early_stopping.best_epoch,base_model_early_stopping.best_epoch], plt.ylim(), label='Best Epoch')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
if not USE_WHOLE_DATASET:
  plt.plot(val_loss, label='Validation Loss')
plt.ylim([0,max(plt.ylim())])
if not USE_WHOLE_DATASET:
  plt.plot([base_model_early_stopping.best_epoch,base_model_early_stopping.best_epoch], plt.ylim(), label='Best Epoch')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Save model

# %%
base_model_directory = f'models/{base_model_supernet.name}-{datetime.today().strftime("%Y-%m-%d-%H-%M-%S")}'
base_model.save(base_model_directory)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 91). These functions will not be directly callable after loading.

# %% [markdown]
# ## Fine tuning

# %%
if USE_WHOLE_DATASET:
  FT_MODEL_EPOCHS = 71

FT_MODEL_LEARNING_RATE = 5e-5
FT_MODEL_OPTIMIZER = tf.keras.optimizers.Adam(FT_MODEL_LEARNING_RATE)
FT_MODEL_LOSS = tf.keras.losses.SparseCategoricalCrossentropy()
FT_MODEL_EARLY_STOPPING_PATIENCE = 10
FT_MODEL_N_UNFREEZE = 30

# %% [markdown]
# ### Reload model

# %%
ft_model = tf.keras.models.load_model(base_model_directory)
ft_model.summary()
print("Number of layers in the supernet: ", len(ft_model.get_layer(base_model_supernet.name).layers))
# Out:
# Model: "base_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data_augmentation (Sequenti  (None, 96, 96, 3)        0
#  al)
#
#  efficientnetv2-b0 (Function  (None, 3, 3, 1280)       5919312
#  al)
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1280)       5120
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 3, 3, 1280)        0
#
#  flatten_1 (Flatten)         (None, 11520)             0
#
#  dense_5 (Dense)             (None, 1024)              11797504
#
#  dense_6 (Dense)             (None, 512)               524800
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  output (Dense)              (None, 8)                 1032
#
# =================================================================
# Total params: 18,428,504
# Trainable params: 12,506,632
# Non-trainable params: 5,921,872
# _________________________________________________________________
# Number of layers in the supernet:  270

# %% [markdown]
# ### Unfreeze some layers

# %%
ft_model.get_layer(base_model_supernet.name).trainable = True

unfreezed = 0
for i in reversed(range(len(ft_model.get_layer(base_model_supernet.name).layers))):
  layer = ft_model.get_layer(base_model_supernet.name).layers[i]
  if layer.name == 'block6d_se_excite':
      layer.trainable = True
  elif unfreezed < FT_MODEL_N_UNFREEZE and not isinstance(layer, tf.keras.layers.BatchNormalization):
      unfreezed += 1
      layer.trainable = True
  else:
    layer.trainable = False
  
  print(i, layer.name, layer.trainable)


ft_model.summary()
# Out:
# 269 top_activation True
# 268 top_bn False
# 267 top_conv True
# 266 block6h_add True
# 265 block6h_drop True
# 264 block6h_project_bn False
# 263 block6h_project_conv True
# 262 block6h_se_excite True
# 261 block6h_se_expand True
# 260 block6h_se_reduce True
# 259 block6h_se_reshape True
# 258 block6h_se_squeeze True
# 257 block6h_activation True
# 256 block6h_bn False
# 255 block6h_dwconv2 True
# 254 block6h_expand_activation True
# 253 block6h_expand_bn False
# 252 block6h_expand_conv True
# 251 block6g_add True
# 250 block6g_drop True
# 249 block6g_project_bn False
# 248 block6g_project_conv True
# 247 block6g_se_excite True
# 246 block6g_se_expand True
# 245 block6g_se_reduce True
# 244 block6g_se_reshape True
# 243 block6g_se_squeeze True
# 242 block6g_activation True
# 241 block6g_bn False
# 240 block6g_dwconv2 True
# 239 block6g_expand_activation True
# 238 block6g_expand_bn False
# 237 block6g_expand_conv True
# 236 block6f_add True
# 235 block6f_drop True
# 234 block6f_project_bn False
# 233 block6f_project_conv True
# 232 block6f_se_excite True
# 231 block6f_se_expand False
# 230 block6f_se_reduce False
# 229 block6f_se_reshape False
# 228 block6f_se_squeeze False
# 227 block6f_activation False
# 226 block6f_bn False
# 225 block6f_dwconv2 False
# 224 block6f_expand_activation False
# 223 block6f_expand_bn False
# 222 block6f_expand_conv False
# 221 block6e_add False
# 220 block6e_drop False
# 219 block6e_project_bn False
# 218 block6e_project_conv False
# 217 block6e_se_excite False
# 216 block6e_se_expand False
# 215 block6e_se_reduce False
# 214 block6e_se_reshape False
# 213 block6e_se_squeeze False
# 212 block6e_activation False
# 211 block6e_bn False
# 210 block6e_dwconv2 False
# 209 block6e_expand_activation False
# 208 block6e_expand_bn False
# 207 block6e_expand_conv False
# 206 block6d_add False
# 205 block6d_drop False
# 204 block6d_project_bn False
# 203 block6d_project_conv False
# 202 block6d_se_excite True
# 201 block6d_se_expand False
# 200 block6d_se_reduce False
# 199 block6d_se_reshape False
# 198 block6d_se_squeeze False
# 197 block6d_activation False
# 196 block6d_bn False
# 195 block6d_dwconv2 False
# 194 block6d_expand_activation False
# 193 block6d_expand_bn False
# 192 block6d_expand_conv False
# 191 block6c_add False
# 190 block6c_drop False
# 189 block6c_project_bn False
# 188 block6c_project_conv False
# 187 block6c_se_excite False
# 186 block6c_se_expand False
# 185 block6c_se_reduce False
# 184 block6c_se_reshape False
# 183 block6c_se_squeeze False
# 182 block6c_activation False
# 181 block6c_bn False
# 180 block6c_dwconv2 False
# 179 block6c_expand_activation False
# 178 block6c_expand_bn False
# 177 block6c_expand_conv False
# 176 block6b_add False
# 175 block6b_drop False
# 174 block6b_project_bn False
# 173 block6b_project_conv False
# 172 block6b_se_excite False
# 171 block6b_se_expand False
# 170 block6b_se_reduce False
# 169 block6b_se_reshape False
# 168 block6b_se_squeeze False
# 167 block6b_activation False
# 166 block6b_bn False
# 165 block6b_dwconv2 False
# 164 block6b_expand_activation False
# 163 block6b_expand_bn False
# 162 block6b_expand_conv False
# 161 block6a_project_bn False
# 160 block6a_project_conv False
# 159 block6a_se_excite False
# 158 block6a_se_expand False
# 157 block6a_se_reduce False
# 156 block6a_se_reshape False
# 155 block6a_se_squeeze False
# 154 block6a_activation False
# 153 block6a_bn False
# 152 block6a_dwconv2 False
# 151 block6a_expand_activation False
# 150 block6a_expand_bn False
# 149 block6a_expand_conv False
# 148 block5e_add False
# 147 block5e_drop False
# 146 block5e_project_bn False
# 145 block5e_project_conv False
# 144 block5e_se_excite False
# 143 block5e_se_expand False
# 142 block5e_se_reduce False
# 141 block5e_se_reshape False
# 140 block5e_se_squeeze False
# 139 block5e_activation False
# 138 block5e_bn False
# 137 block5e_dwconv2 False
# 136 block5e_expand_activation False
# 135 block5e_expand_bn False
# 134 block5e_expand_conv False
# 133 block5d_add False
# 132 block5d_drop False
# 131 block5d_project_bn False
# 130 block5d_project_conv False
# 129 block5d_se_excite False
# 128 block5d_se_expand False
# 127 block5d_se_reduce False
# 126 block5d_se_reshape False
# 125 block5d_se_squeeze False
# 124 block5d_activation False
# 123 block5d_bn False
# 122 block5d_dwconv2 False
# 121 block5d_expand_activation False
# 120 block5d_expand_bn False
# 119 block5d_expand_conv False
# 118 block5c_add False
# 117 block5c_drop False
# 116 block5c_project_bn False
# 115 block5c_project_conv False
# 114 block5c_se_excite False
# 113 block5c_se_expand False
# 112 block5c_se_reduce False
# 111 block5c_se_reshape False
# 110 block5c_se_squeeze False
# 109 block5c_activation False
# 108 block5c_bn False
# 107 block5c_dwconv2 False
# 106 block5c_expand_activation False
# 105 block5c_expand_bn False
# 104 block5c_expand_conv False
# 103 block5b_add False
# 102 block5b_drop False
# 101 block5b_project_bn False
# 100 block5b_project_conv False
# 99 block5b_se_excite False
# 98 block5b_se_expand False
# 97 block5b_se_reduce False
# 96 block5b_se_reshape False
# 95 block5b_se_squeeze False
# 94 block5b_activation False
# 93 block5b_bn False
# 92 block5b_dwconv2 False
# 91 block5b_expand_activation False
# 90 block5b_expand_bn False
# 89 block5b_expand_conv False
# 88 block5a_project_bn False
# 87 block5a_project_conv False
# 86 block5a_se_excite False
# 85 block5a_se_expand False
# 84 block5a_se_reduce False
# 83 block5a_se_reshape False
# 82 block5a_se_squeeze False
# 81 block5a_activation False
# 80 block5a_bn False
# 79 block5a_dwconv2 False
# 78 block5a_expand_activation False
# 77 block5a_expand_bn False
# 76 block5a_expand_conv False
# 75 block4c_add False
# 74 block4c_drop False
# 73 block4c_project_bn False
# 72 block4c_project_conv False
# 71 block4c_se_excite False
# 70 block4c_se_expand False
# 69 block4c_se_reduce False
# 68 block4c_se_reshape False
# 67 block4c_se_squeeze False
# 66 block4c_activation False
# 65 block4c_bn False
# 64 block4c_dwconv2 False
# 63 block4c_expand_activation False
# 62 block4c_expand_bn False
# 61 block4c_expand_conv False
# 60 block4b_add False
# 59 block4b_drop False
# 58 block4b_project_bn False
# 57 block4b_project_conv False
# 56 block4b_se_excite False
# 55 block4b_se_expand False
# 54 block4b_se_reduce False
# 53 block4b_se_reshape False
# 52 block4b_se_squeeze False
# 51 block4b_activation False
# 50 block4b_bn False
# 49 block4b_dwconv2 False
# 48 block4b_expand_activation False
# 47 block4b_expand_bn False
# 46 block4b_expand_conv False
# 45 block4a_project_bn False
# 44 block4a_project_conv False
# 43 block4a_se_excite False
# 42 block4a_se_expand False
# 41 block4a_se_reduce False
# 40 block4a_se_reshape False
# 39 block4a_se_squeeze False
# 38 block4a_activation False
# 37 block4a_bn False
# 36 block4a_dwconv2 False
# 35 block4a_expand_activation False
# 34 block4a_expand_bn False
# 33 block4a_expand_conv False
# 32 block3b_add False
# 31 block3b_drop False
# 30 block3b_project_bn False
# 29 block3b_project_conv False
# 28 block3b_expand_activation False
# 27 block3b_expand_bn False
# 26 block3b_expand_conv False
# 25 block3a_project_bn False
# 24 block3a_project_conv False
# 23 block3a_expand_activation False
# 22 block3a_expand_bn False
# 21 block3a_expand_conv False
# 20 block2b_add False
# 19 block2b_drop False
# 18 block2b_project_bn False
# 17 block2b_project_conv False
# 16 block2b_expand_activation False
# 15 block2b_expand_bn False
# 14 block2b_expand_conv False
# 13 block2a_project_bn False
# 12 block2a_project_conv False
# 11 block2a_expand_activation False
# 10 block2a_expand_bn False
# 9 block2a_expand_conv False
# 8 block1a_project_activation False
# 7 block1a_project_bn False
# 6 block1a_project_conv False
# 5 stem_activation False
# 4 stem_bn False
# 3 stem_conv False
# 2 normalization_1 False
# 1 rescaling_1 False
# 0 input_2 False
# Model: "base_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data_augmentation (Sequenti  (None, 96, 96, 3)        0
#  al)
#
#  efficientnetv2-b0 (Function  (None, 3, 3, 1280)       5919312
#  al)
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1280)       5120
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 3, 3, 1280)        0
#
#  flatten_1 (Flatten)         (None, 11520)             0
#
#  dense_5 (Dense)             (None, 1024)              11797504
#
#  dense_6 (Dense)             (None, 512)               524800
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  output (Dense)              (None, 8)                 1032
#
# =================================================================
# Total params: 18,428,504
# Trainable params: 14,102,632
# Non-trainable params: 4,325,872
# _________________________________________________________________

# %% [markdown]
# ### Compile and train

# %%
ft_model.compile(
    optimizer=FT_MODEL_OPTIMIZER,
    loss=FT_MODEL_LOSS,
    metrics=['accuracy']
)
ft_model.summary()
# Out:
# Model: "base_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data_augmentation (Sequenti  (None, 96, 96, 3)        0
#  al)
#
#  efficientnetv2-b0 (Function  (None, 3, 3, 1280)       5919312
#  al)
#
#  batch_normalization_1 (Batc  (None, 3, 3, 1280)       5120
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 3, 3, 1280)        0
#
#  flatten_1 (Flatten)         (None, 11520)             0
#
#  dense_5 (Dense)             (None, 1024)              11797504
#
#  dense_6 (Dense)             (None, 512)               524800
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  output (Dense)              (None, 8)                 1032
#
# =================================================================
# Total params: 18,428,504
# Trainable params: 14,102,632
# Non-trainable params: 4,325,872
# _________________________________________________________________

# %%
if USE_WHOLE_DATASET:
  ft_history = ft_model.fit(
    complete_ds,
    epochs=FT_MODEL_EPOCHS,
    initial_epoch=BASE_MODEL_EPOCHS
  )
else:
  # use early stopping
  ft_max_epochs = 100
  ft_total_epochs =  base_model_early_stopping.best_epoch + ft_max_epochs

  ft_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=FT_MODEL_EARLY_STOPPING_PATIENCE, restore_best_weights=True)

  ft_history = ft_model.fit(
      train_ds,
      epochs=ft_total_epochs,
      initial_epoch=base_model_early_stopping.best_epoch,
      validation_data=val_ds,
      callbacks = [ft_early_stopping]
  )
# Out:
# Epoch 40/71
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# 56/56 [==============================] - 48s 670ms/step - loss: 0.6843 - accuracy: 0.7660
# Epoch 41/71
# 56/56 [==============================] - 36s 645ms/step - loss: 0.6281 - accuracy: 0.7888
# Epoch 42/71
# 56/56 [==============================] - 36s 645ms/step - loss: 0.6155 - accuracy: 0.7902
# Epoch 43/71
# 56/56 [==============================] - 36s 636ms/step - loss: 0.6185 - accuracy: 0.7823
# Epoch 44/71
# 56/56 [==============================] - 36s 638ms/step - loss: 0.5924 - accuracy: 0.7914
# Epoch 45/71
# 56/56 [==============================] - 36s 637ms/step - loss: 0.5769 - accuracy: 0.7987
# Epoch 46/71
# 56/56 [==============================] - 36s 637ms/step - loss: 0.5825 - accuracy: 0.7919
# Epoch 47/71
# 56/56 [==============================] - 37s 668ms/step - loss: 0.5625 - accuracy: 0.8012
# Epoch 48/71
# 56/56 [==============================] - 36s 636ms/step - loss: 0.5787 - accuracy: 0.8010
# Epoch 49/71
# 56/56 [==============================] - 36s 642ms/step - loss: 0.5493 - accuracy: 0.8004
# Epoch 50/71
# 56/56 [==============================] - 36s 640ms/step - loss: 0.5525 - accuracy: 0.8072
# Epoch 51/71
# 56/56 [==============================] - 36s 642ms/step - loss: 0.5516 - accuracy: 0.8043
# Epoch 52/71
# 56/56 [==============================] - 36s 639ms/step - loss: 0.5592 - accuracy: 0.8015
# Epoch 53/71
# 56/56 [==============================] - 36s 649ms/step - loss: 0.5664 - accuracy: 0.7936
# Epoch 54/71
# 56/56 [==============================] - 36s 640ms/step - loss: 0.5363 - accuracy: 0.8024
# Epoch 55/71
# 56/56 [==============================] - 36s 639ms/step - loss: 0.5499 - accuracy: 0.8069
# Epoch 56/71
# 56/56 [==============================] - 36s 639ms/step - loss: 0.5448 - accuracy: 0.7993
# Epoch 57/71
# 56/56 [==============================] - 36s 641ms/step - loss: 0.5472 - accuracy: 0.8148
# Epoch 58/71
# 56/56 [==============================] - 36s 638ms/step - loss: 0.5389 - accuracy: 0.8080
# Epoch 59/71
# 56/56 [==============================] - 36s 640ms/step - loss: 0.5379 - accuracy: 0.8075
# Epoch 60/71
# 56/56 [==============================] - 37s 668ms/step - loss: 0.5197 - accuracy: 0.8156
# Epoch 61/71
# 56/56 [==============================] - 36s 638ms/step - loss: 0.5299 - accuracy: 0.8094
# Epoch 62/71
# 56/56 [==============================] - 36s 641ms/step - loss: 0.5210 - accuracy: 0.8176
# Epoch 63/71
# 56/56 [==============================] - 36s 640ms/step - loss: 0.5440 - accuracy: 0.8080
# Epoch 64/71
# 56/56 [==============================] - 36s 637ms/step - loss: 0.5250 - accuracy: 0.8114
# Epoch 65/71
# 56/56 [==============================] - 36s 642ms/step - loss: 0.5178 - accuracy: 0.8168
# Epoch 66/71
# 56/56 [==============================] - 36s 643ms/step - loss: 0.5046 - accuracy: 0.8182
# Epoch 67/71
# 56/56 [==============================] - 38s 671ms/step - loss: 0.5127 - accuracy: 0.8210
# Epoch 68/71
# 56/56 [==============================] - 36s 640ms/step - loss: 0.4966 - accuracy: 0.8224
# Epoch 69/71
# 56/56 [==============================] - 36s 639ms/step - loss: 0.5166 - accuracy: 0.8173
# Epoch 70/71
# 56/56 [==============================] - 36s 640ms/step - loss: 0.5140 - accuracy: 0.8224
# Epoch 71/71
# 56/56 [==============================] - 36s 637ms/step - loss: 0.5040 - accuracy: 0.8176

# %% [markdown]
# ### Visualize results

# %%
acc += ft_history.history['accuracy']
if not USE_WHOLE_DATASET:
  val_acc += ft_history.history['val_accuracy']

loss += ft_history.history['loss']
if not USE_WHOLE_DATASET:
  val_loss += ft_history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
if not USE_WHOLE_DATASET:
  plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([min(plt.ylim()),1])
if not USE_WHOLE_DATASET:
  plt.plot([ft_early_stopping.best_epoch,ft_early_stopping.best_epoch],
         plt.ylim(), label='Best Epoch')
if not USE_WHOLE_DATASET:
  plt.plot([base_model_early_stopping.best_epoch, base_model_early_stopping.best_epoch],
          plt.ylim(), label='Start Fine Tuning')
else:
  plt.plot([BASE_MODEL_EPOCHS, BASE_MODEL_EPOCHS],
          plt.ylim(), label='Start Fine Tuning')

plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
if not USE_WHOLE_DATASET:
  plt.plot(val_loss, label='Validation Loss')
plt.ylim([0,max(plt.ylim())])
if not USE_WHOLE_DATASET:
  plt.plot([ft_early_stopping.best_epoch,ft_early_stopping.best_epoch],
         plt.ylim(), label='Best Epoch')
if not USE_WHOLE_DATASET:
  plt.plot([base_model_early_stopping.best_epoch, base_model_early_stopping.best_epoch],
          plt.ylim(), label='Start Fine Tuning')
else:
  plt.plot([BASE_MODEL_EPOCHS, BASE_MODEL_EPOCHS],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Save model

# %% [markdown]
# Save newly trained fine tuned model

# %%
ft_model_directory = f'models/{base_model_supernet.name}-finetuned-{datetime.today().strftime("%Y-%m-%d-%H-%M-%S")}'
ft_model.save(ft_model_directory)
if IS_COLAB:
  from shutil import make_archive, copyfile
  make_archive(ft_model_directory, 'zip', ft_model_directory)
  copyfile(ft_model_directory + '.zip', COLAB_BASE_DIR + ft_model_directory)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer-0.layer-0._random_generator._generator._state_var
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer-0.layer-1._random_generator._generator._state_var
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer-0.layer-2._random_generator._generator._state_var
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer-0.layer-3._random_generator._generator._state_var
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer-0.layer-4._random_generator._generator._state_var
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 91). These functions will not be directly callable after loading.
