# %% [markdown]
# # Image Classification challange AN2DL Politecnico di Milano 2022
# This is ..

# %% [markdown]
# ## Define the environment
# 1. **Colab**: the notebook must be in a folder where there is a folder called `data` and the `zip` file containing the training data inside (i.e. `data/training_dataset_homework1.zip`).
# 2. **Local**: extract the `zip` file containing the training data in `data/training_data_final`

# %%
IS_COLAB = False
COLAB_BASE_DIR = '/gdrive/MyDrive/colab/AN2DL1/'
USE_WHOLE_DATASET = False # if True do not perform validation and analysis, just train with all the data

# %% [markdown]
# ## Libraries import

# %%
import os
import enum
import json
from datetime import datetime
import random
from typing import Tuple, Callable, Dict, Optional, List

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Check device
tf.test.gpu_device_name()
# Out:
# ''

# %% [markdown]
# ### Seed

# %%
# Random seed for reproducibility
SEED = 42

random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ### Mount Google Drive (if using Colab)

# %%
if IS_COLAB:
    from google.colab import drive
    drive.mount('/gdrive')

# %% [markdown]
# ### Check folders

# %%
ROOT_DIR = os.getcwd()
DATA_DIR = 'data/training_data_final'

if IS_COLAB:
  if not os.path.exists('data'):
    # !mkdir 'data'
  if not os.path.isfile('data/training_dataset_homework1.zip'):
    zip_source = COLAB_BASE_DIR + 'data/training_dataset_homework1.zip'
    # !cp $zip_source 'data'
  if not os.path.exists(DATA_DIR):
    # !unzip 'data/training_dataset_homework1' -d 'data'
else:
  if not os.path.exists('data'):
    raise RuntimeError("data/training_data_final path not found.")
  if not os.path.exists(DATA_DIR):
    raise RuntimeError("please unzip data/training_dataset_homework1.zip")

# %% [markdown]
# ## Load datasets

# %% [markdown]
# Define datasets hyperparameters

# %%
VALIDATION_SPLIT = 0.2
BATCH_SIZE = 64

# %%
IMG_SIZE = (96, 96)
IMG_SHAPE = IMG_SIZE + (3,)
N_CLASSES = 8

if USE_WHOLE_DATASET:
    complete_ds = tf.keras.utils.image_dataset_from_directory(
        DATA_DIR,
        labels='inferred',
        label_mode='int',
        color_mode='rgb',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        shuffle=True,
        seed=SEED,
    )
else:
    train_ds = tf.keras.utils.image_dataset_from_directory(
        DATA_DIR,
        labels='inferred',
        label_mode='int',
        color_mode='rgb',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        shuffle=True,
        seed=SEED,
        validation_split=VALIDATION_SPLIT,
        subset = 'training'
    )

    val_ds = tf.keras.utils.image_dataset_from_directory(
        DATA_DIR,
        labels='inferred',
        label_mode='int',
        color_mode='rgb',
        batch_size=BATCH_SIZE,
        image_size=IMG_SIZE,
        shuffle=True,
        seed=SEED,
        validation_split=VALIDATION_SPLIT,
        subset = 'validation'
    )
# Out:
# Found 3542 files belonging to 8 classes.
# Using 2834 files for training.
# Found 3542 files belonging to 8 classes.
# Using 708 files for validation.

# %% [markdown]
# Configure the dataset for performance, see the [Better performance with the tf.data API](https://www.tensorflow.org/guide/data_performance) guide:

# %%
AUTOTUNE = tf.data.AUTOTUNE

if USE_WHOLE_DATASET:
  complete_ds = complete_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
else:
  train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
  val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Preprocessing and Data Augmentation

# %%
data_augmentation_layer = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomContrast(0.1),
  #tf.keras.layers.RandomBrightness(0.01),
  tf.keras.layers.RandomZoom(0.1),
  #tf.keras.layers.RandomTranslation(0.1, 0.1)
], name='data_augmentation')

if False:
  for image, _ in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
      ax = plt.subplot(3, 3, i + 1)
      augmented_image = data_augmentation_layer(tf.expand_dims(first_image, 0))
      plt.imshow(augmented_image[0] / 255)
      plt.axis('off')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "images" of op 'AdjustContrastv2' expected to be not loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "images" of op 'AdjustContrastv2' expected to be not loop invariant.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x00000214370D4DC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x00000214410DC940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "images" of op 'AdjustContrastv2' expected to be not loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "images" of op 'AdjustContrastv2' expected to be not loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "images" of op 'AdjustContrastv2' expected to be not loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "images" of op 'AdjustContrastv2' expected to be not loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "images" of op 'AdjustContrastv2' expected to be not loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "images" of op 'AdjustContrastv2' expected to be not loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "images" of op 'AdjustContrastv2' expected to be not loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# ## Base model

# %%
if USE_WHOLE_DATASET:
  BASE_MODEL_EPOCHS = 70

BASE_MODEL_LEARNING_RATE = 1e-3
BASE_MODEL_OPTIMIZER = tf.keras.optimizers.Adam(BASE_MODEL_LEARNING_RATE)
BASE_MODEL_LOSS = tf.keras.losses.SparseCategoricalCrossentropy()
BASE_MODEL_EARLY_STOPPING_PATIENCE = 30

# %%
base_model_supernet = tf.keras.applications.EfficientNetV2B1(
    input_shape=IMG_SHAPE,
    include_top=False,
    weights='imagenet'
)
base_model_supernet.trainable = False

# %%
base_model = tf.keras.Sequential([
    tf.keras.Input(shape=IMG_SHAPE, name="input"),
    data_augmentation_layer,
    tf.keras.layers.Lambda(tf.keras.applications.efficientnet_v2.preprocess_input , name="supernet_preprocessing"),
    base_model_supernet,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(2048, activation='relu', kernel_initializer=tf.keras.initializers.HeUniform(SEED)),
    tf.keras.layers.Dense(1024, activation='relu', kernel_initializer=tf.keras.initializers.HeUniform(SEED)),
    tf.keras.layers.Dense(N_CLASSES, name='output', activation='softmax', kernel_initializer=tf.keras.initializers.GlorotUniform(SEED))
], name="base_model")

# %%
base_model.compile(
    optimizer=BASE_MODEL_OPTIMIZER,
    loss=BASE_MODEL_LOSS,
    metrics=['accuracy']
)
base_model.summary()
# Out:
# Model: "base_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data_augmentation (Sequenti  (None, 96, 96, 3)        0
#  al)
#
#  supernet_preprocessing (Lam  (None, 96, 96, 3)        0
#  bda)
#
#  efficientnetv2-b1 (Function  (None, 3, 3, 1280)       6931124
#  al)
#
#  flatten (Flatten)           (None, 11520)             0
#
#  dropout (Dropout)           (None, 11520)             0
#
#  dense (Dense)               (None, 2048)              23595008
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  output (Dense)              (None, 8)                 8200
#
# =================================================================
# Total params: 32,632,508
# Trainable params: 25,701,384
# Non-trainable params: 6,931,124
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
if USE_WHOLE_DATASET:
  base_model_history = base_model.fit(
    complete_ds,
    epochs=BASE_MODEL_EPOCHS
  )
else:
  # use early stopping
  base_model_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=BASE_MODEL_EARLY_STOPPING_PATIENCE, restore_best_weights=True)
  base_model_history = base_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=200,
    callbacks = [base_model_early_stopping],
  )
# Out:
# Epoch 1/200
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 45/45 [==============================] - 51s 820ms/step - loss: 1.9843 - accuracy: 0.4481 - val_loss: 1.0958 - val_accuracy: 0.5749
# Epoch 2/200
# 45/45 [==============================] - 32s 718ms/step - loss: 1.1168 - accuracy: 0.5974 - val_loss: 0.9981 - val_accuracy: 0.6314
# Epoch 3/200
# 45/45 [==============================] - 33s 726ms/step - loss: 1.0035 - accuracy: 0.6489 - val_loss: 0.8871 - val_accuracy: 0.6921
# Epoch 4/200
# 45/45 [==============================] - 33s 727ms/step - loss: 0.9461 - accuracy: 0.6574 - val_loss: 0.8863 - val_accuracy: 0.6751
# Epoch 5/200
# 45/45 [==============================] - 38s 858ms/step - loss: 0.9059 - accuracy: 0.6694 - val_loss: 0.8533 - val_accuracy: 0.6921
# Epoch 6/200
# 45/45 [==============================] - 32s 712ms/step - loss: 0.8476 - accuracy: 0.6888 - val_loss: 0.9239 - val_accuracy: 0.6907
# Epoch 7/200
# 45/45 [==============================] - 33s 725ms/step - loss: 0.8459 - accuracy: 0.6877 - val_loss: 0.9583 - val_accuracy: 0.6582
# Epoch 8/200
# 45/45 [==============================] - 33s 740ms/step - loss: 0.7779 - accuracy: 0.7181 - val_loss: 0.8482 - val_accuracy: 0.6963
# Epoch 9/200
#  6/45 [===>..........................] - ETA: 19s - loss: 0.8883 - accuracy: 0.6568
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [14], line 9
#       6 else:
#       7   # use early stopping
#       8   base_model_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=BASE_MODEL_EARLY_STOPPING_PATIENCE, restore_best_weights=True)
# ----> 9   base_model_history = base_model.fit(
#      10     train_ds,
#      11     validation_data=val_ds,
#      12     epochs=200,
#      13     callbacks = [base_model_early_stopping],
#      14   )
#
# File d:\Paolo\Developing\an2dl-image-classification\.venv\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Paolo\Developing\an2dl-image-classification\.venv\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File d:\Paolo\Developing\an2dl-image-classification\.venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Paolo\Developing\an2dl-image-classification\.venv\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\Paolo\Developing\an2dl-image-classification\.venv\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File d:\Paolo\Developing\an2dl-image-classification\.venv\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File d:\Paolo\Developing\an2dl-image-classification\.venv\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\Paolo\Developing\an2dl-image-classification\.venv\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File d:\Paolo\Developing\an2dl-image-classification\.venv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualize performance

# %%
acc = base_model_history.history['accuracy']
if not USE_WHOLE_DATASET:
  val_acc = base_model_history.history['val_accuracy']

loss = base_model_history.history['loss']
if not USE_WHOLE_DATASET:
  val_loss = base_model_history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
if not USE_WHOLE_DATASET:
  plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([min(plt.ylim()),1])
if not USE_WHOLE_DATASET:
  plt.plot([base_model_early_stopping.best_epoch,base_model_early_stopping.best_epoch], plt.ylim(), label='Best Epoch')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
if not USE_WHOLE_DATASET:
  plt.plot(val_loss, label='Validation Loss')
plt.ylim([0,max(plt.ylim())])
if not USE_WHOLE_DATASET:
  plt.plot([base_model_early_stopping.best_epoch,base_model_early_stopping.best_epoch], plt.ylim(), label='Best Epoch')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Save model

# %%
base_model_directory = f'models/{base_model_supernet.name}-{datetime.today().strftime("%Y-%m-%d-%H-%M-%S")}'
base_model.save(base_model_directory)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 111). These functions will not be directly callable after loading.

# %% [markdown]
# ## Fine tuning

# %%
if USE_WHOLE_DATASET:
  FT_MODEL_EPOCHS = 100

FT_MODEL_LEARNING_RATE = 5e-5
FT_MODEL_OPTIMIZER = tf.keras.optimizers.Adam(FT_MODEL_LEARNING_RATE)
FT_MODEL_LOSS = tf.keras.losses.SparseCategoricalCrossentropy()
FT_MODEL_EARLY_STOPPING_PATIENCE = 30
FT_MODEL_N_UNFREEZE = 50

# %% [markdown]
# ### Reload model

# %%
ft_model = tf.keras.models.load_model(base_model_directory)
ft_model.summary()
print("Number of layers in the supernet: ", len(ft_model.get_layer(base_model_supernet.name).layers))
# Out:
# Model: "base_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data_augmentation (Sequenti  (None, 96, 96, 3)        0
#  al)
#
#  supernet_preprocessing (Lam  (None, 96, 96, 3)        0
#  bda)
#
#  efficientnetv2-b1 (Function  (None, 3, 3, 1280)       6931124
#  al)
#
#  flatten_13 (Flatten)        (None, 11520)             0
#
#  dropout_13 (Dropout)        (None, 11520)             0
#
#  dense_27 (Dense)            (None, 1024)              11797504
#
#  dense_28 (Dense)            (None, 512)               524800
#
#  output (Dense)              (None, 8)                 4104
#
# =================================================================
# Total params: 19,257,532
# Trainable params: 12,326,408
# Non-trainable params: 6,931,124
# _________________________________________________________________
# Number of layers in the supernet:  334

# %% [markdown]
# ### Unfreeze some layers

# %%
ft_model.get_layer(base_model_supernet.name).trainable = True

unfreezed = 0
for i in reversed(range(len(ft_model.get_layer(base_model_supernet.name).layers))):
  layer = ft_model.get_layer(base_model_supernet.name).layers[i]
  if layer.name == 'block6d_se_excite':
      layer.trainable = True
  elif unfreezed < FT_MODEL_N_UNFREEZE and not isinstance(layer, tf.keras.layers.BatchNormalization):
      unfreezed += 1
      layer.trainable = True
  else:
    layer.trainable = False
  
  print(i, layer.name, layer.trainable)


ft_model.summary()
# Out:
# 333 top_activation True
# 332 top_bn False
# 331 top_conv True
# 330 block6i_add True
# 329 block6i_drop True
# 328 block6i_project_bn False
# 327 block6i_project_conv True
# 326 block6i_se_excite True
# 325 block6i_se_expand True
# 324 block6i_se_reduce True
# 323 block6i_se_reshape True
# 322 block6i_se_squeeze True
# 321 block6i_activation True
# 320 block6i_bn False
# 319 block6i_dwconv2 True
# 318 block6i_expand_activation True
# 317 block6i_expand_bn False
# 316 block6i_expand_conv True
# 315 block6h_add True
# 314 block6h_drop True
# 313 block6h_project_bn False
# 312 block6h_project_conv True
# 311 block6h_se_excite True
# 310 block6h_se_expand True
# 309 block6h_se_reduce True
# 308 block6h_se_reshape True
# 307 block6h_se_squeeze True
# 306 block6h_activation True
# 305 block6h_bn False
# 304 block6h_dwconv2 True
# 303 block6h_expand_activation True
# 302 block6h_expand_bn False
# 301 block6h_expand_conv True
# 300 block6g_add True
# 299 block6g_drop True
# 298 block6g_project_bn False
# 297 block6g_project_conv True
# 296 block6g_se_excite True
# 295 block6g_se_expand True
# 294 block6g_se_reduce True
# 293 block6g_se_reshape True
# 292 block6g_se_squeeze True
# 291 block6g_activation True
# 290 block6g_bn False
# 289 block6g_dwconv2 True
# 288 block6g_expand_activation True
# 287 block6g_expand_bn False
# 286 block6g_expand_conv True
# 285 block6f_add True
# 284 block6f_drop True
# 283 block6f_project_bn False
# 282 block6f_project_conv True
# 281 block6f_se_excite True
# 280 block6f_se_expand True
# 279 block6f_se_reduce True
# 278 block6f_se_reshape True
# 277 block6f_se_squeeze True
# 276 block6f_activation True
# 275 block6f_bn False
# 274 block6f_dwconv2 True
# 273 block6f_expand_activation True
# 272 block6f_expand_bn False
# 271 block6f_expand_conv True
# 270 block6e_add False
# 269 block6e_drop False
# 268 block6e_project_bn False
# 267 block6e_project_conv False
# 266 block6e_se_excite False
# 265 block6e_se_expand False
# 264 block6e_se_reduce False
# 263 block6e_se_reshape False
# 262 block6e_se_squeeze False
# 261 block6e_activation False
# 260 block6e_bn False
# 259 block6e_dwconv2 False
# 258 block6e_expand_activation False
# 257 block6e_expand_bn False
# 256 block6e_expand_conv False
# 255 block6d_add False
# 254 block6d_drop False
# 253 block6d_project_bn False
# 252 block6d_project_conv False
# 251 block6d_se_excite True
# 250 block6d_se_expand False
# 249 block6d_se_reduce False
# 248 block6d_se_reshape False
# 247 block6d_se_squeeze False
# 246 block6d_activation False
# 245 block6d_bn False
# 244 block6d_dwconv2 False
# 243 block6d_expand_activation False
# 242 block6d_expand_bn False
# 241 block6d_expand_conv False
# 240 block6c_add False
# 239 block6c_drop False
# 238 block6c_project_bn False
# 237 block6c_project_conv False
# 236 block6c_se_excite False
# 235 block6c_se_expand False
# 234 block6c_se_reduce False
# 233 block6c_se_reshape False
# 232 block6c_se_squeeze False
# 231 block6c_activation False
# 230 block6c_bn False
# 229 block6c_dwconv2 False
# 228 block6c_expand_activation False
# 227 block6c_expand_bn False
# 226 block6c_expand_conv False
# 225 block6b_add False
# 224 block6b_drop False
# 223 block6b_project_bn False
# 222 block6b_project_conv False
# 221 block6b_se_excite False
# 220 block6b_se_expand False
# 219 block6b_se_reduce False
# 218 block6b_se_reshape False
# 217 block6b_se_squeeze False
# 216 block6b_activation False
# 215 block6b_bn False
# 214 block6b_dwconv2 False
# 213 block6b_expand_activation False
# 212 block6b_expand_bn False
# 211 block6b_expand_conv False
# 210 block6a_project_bn False
# 209 block6a_project_conv False
# 208 block6a_se_excite False
# 207 block6a_se_expand False
# 206 block6a_se_reduce False
# 205 block6a_se_reshape False
# 204 block6a_se_squeeze False
# 203 block6a_activation False
# 202 block6a_bn False
# 201 block6a_dwconv2 False
# 200 block6a_expand_activation False
# 199 block6a_expand_bn False
# 198 block6a_expand_conv False
# 197 block5f_add False
# 196 block5f_drop False
# 195 block5f_project_bn False
# 194 block5f_project_conv False
# 193 block5f_se_excite False
# 192 block5f_se_expand False
# 191 block5f_se_reduce False
# 190 block5f_se_reshape False
# 189 block5f_se_squeeze False
# 188 block5f_activation False
# 187 block5f_bn False
# 186 block5f_dwconv2 False
# 185 block5f_expand_activation False
# 184 block5f_expand_bn False
# 183 block5f_expand_conv False
# 182 block5e_add False
# 181 block5e_drop False
# 180 block5e_project_bn False
# 179 block5e_project_conv False
# 178 block5e_se_excite False
# 177 block5e_se_expand False
# 176 block5e_se_reduce False
# 175 block5e_se_reshape False
# 174 block5e_se_squeeze False
# 173 block5e_activation False
# 172 block5e_bn False
# 171 block5e_dwconv2 False
# 170 block5e_expand_activation False
# 169 block5e_expand_bn False
# 168 block5e_expand_conv False
# 167 block5d_add False
# 166 block5d_drop False
# 165 block5d_project_bn False
# 164 block5d_project_conv False
# 163 block5d_se_excite False
# 162 block5d_se_expand False
# 161 block5d_se_reduce False
# 160 block5d_se_reshape False
# 159 block5d_se_squeeze False
# 158 block5d_activation False
# 157 block5d_bn False
# 156 block5d_dwconv2 False
# 155 block5d_expand_activation False
# 154 block5d_expand_bn False
# 153 block5d_expand_conv False
# 152 block5c_add False
# 151 block5c_drop False
# 150 block5c_project_bn False
# 149 block5c_project_conv False
# 148 block5c_se_excite False
# 147 block5c_se_expand False
# 146 block5c_se_reduce False
# 145 block5c_se_reshape False
# 144 block5c_se_squeeze False
# 143 block5c_activation False
# 142 block5c_bn False
# 141 block5c_dwconv2 False
# 140 block5c_expand_activation False
# 139 block5c_expand_bn False
# 138 block5c_expand_conv False
# 137 block5b_add False
# 136 block5b_drop False
# 135 block5b_project_bn False
# 134 block5b_project_conv False
# 133 block5b_se_excite False
# 132 block5b_se_expand False
# 131 block5b_se_reduce False
# 130 block5b_se_reshape False
# 129 block5b_se_squeeze False
# 128 block5b_activation False
# 127 block5b_bn False
# 126 block5b_dwconv2 False
# 125 block5b_expand_activation False
# 124 block5b_expand_bn False
# 123 block5b_expand_conv False
# 122 block5a_project_bn False
# 121 block5a_project_conv False
# 120 block5a_se_excite False
# 119 block5a_se_expand False
# 118 block5a_se_reduce False
# 117 block5a_se_reshape False
# 116 block5a_se_squeeze False
# 115 block5a_activation False
# 114 block5a_bn False
# 113 block5a_dwconv2 False
# 112 block5a_expand_activation False
# 111 block5a_expand_bn False
# 110 block5a_expand_conv False
# 109 block4d_add False
# 108 block4d_drop False
# 107 block4d_project_bn False
# 106 block4d_project_conv False
# 105 block4d_se_excite False
# 104 block4d_se_expand False
# 103 block4d_se_reduce False
# 102 block4d_se_reshape False
# 101 block4d_se_squeeze False
# 100 block4d_activation False
# 99 block4d_bn False
# 98 block4d_dwconv2 False
# 97 block4d_expand_activation False
# 96 block4d_expand_bn False
# 95 block4d_expand_conv False
# 94 block4c_add False
# 93 block4c_drop False
# 92 block4c_project_bn False
# 91 block4c_project_conv False
# 90 block4c_se_excite False
# 89 block4c_se_expand False
# 88 block4c_se_reduce False
# 87 block4c_se_reshape False
# 86 block4c_se_squeeze False
# 85 block4c_activation False
# 84 block4c_bn False
# 83 block4c_dwconv2 False
# 82 block4c_expand_activation False
# 81 block4c_expand_bn False
# 80 block4c_expand_conv False
# 79 block4b_add False
# 78 block4b_drop False
# 77 block4b_project_bn False
# 76 block4b_project_conv False
# 75 block4b_se_excite False
# 74 block4b_se_expand False
# 73 block4b_se_reduce False
# 72 block4b_se_reshape False
# 71 block4b_se_squeeze False
# 70 block4b_activation False
# 69 block4b_bn False
# 68 block4b_dwconv2 False
# 67 block4b_expand_activation False
# 66 block4b_expand_bn False
# 65 block4b_expand_conv False
# 64 block4a_project_bn False
# 63 block4a_project_conv False
# 62 block4a_se_excite False
# 61 block4a_se_expand False
# 60 block4a_se_reduce False
# 59 block4a_se_reshape False
# 58 block4a_se_squeeze False
# 57 block4a_activation False
# 56 block4a_bn False
# 55 block4a_dwconv2 False
# 54 block4a_expand_activation False
# 53 block4a_expand_bn False
# 52 block4a_expand_conv False
# 51 block3c_add False
# 50 block3c_drop False
# 49 block3c_project_bn False
# 48 block3c_project_conv False
# 47 block3c_expand_activation False
# 46 block3c_expand_bn False
# 45 block3c_expand_conv False
# 44 block3b_add False
# 43 block3b_drop False
# 42 block3b_project_bn False
# 41 block3b_project_conv False
# 40 block3b_expand_activation False
# 39 block3b_expand_bn False
# 38 block3b_expand_conv False
# 37 block3a_project_bn False
# 36 block3a_project_conv False
# 35 block3a_expand_activation False
# 34 block3a_expand_bn False
# 33 block3a_expand_conv False
# 32 block2c_add False
# 31 block2c_drop False
# 30 block2c_project_bn False
# 29 block2c_project_conv False
# 28 block2c_expand_activation False
# 27 block2c_expand_bn False
# 26 block2c_expand_conv False
# 25 block2b_add False
# 24 block2b_drop False
# 23 block2b_project_bn False
# 22 block2b_project_conv False
# 21 block2b_expand_activation False
# 20 block2b_expand_bn False
# 19 block2b_expand_conv False
# 18 block2a_project_bn False
# 17 block2a_project_conv False
# 16 block2a_expand_activation False
# 15 block2a_expand_bn False
# 14 block2a_expand_conv False
# 13 block1b_add False
# 12 block1b_drop False
# 11 block1b_project_activation False
# 10 block1b_project_bn False
# 9 block1b_project_conv False
# 8 block1a_project_activation False
# 7 block1a_project_bn False
# 6 block1a_project_conv False
# 5 stem_activation False
# 4 stem_bn False
# 3 stem_conv False
# 2 normalization_3 False
# 1 rescaling_3 False
# 0 input_4 False
# Model: "base_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data_augmentation (Sequenti  (None, 96, 96, 3)        0
#  al)
#
#  supernet_preprocessing (Lam  (None, 96, 96, 3)        0
#  bda)
#
#  efficientnetv2-b1 (Function  (None, 3, 3, 1280)       6931124
#  al)
#
#  flatten_13 (Flatten)        (None, 11520)             0
#
#  dropout_13 (Dropout)        (None, 11520)             0
#
#  dense_27 (Dense)            (None, 1024)              11797504
#
#  dense_28 (Dense)            (None, 512)               524800
#
#  output (Dense)              (None, 8)                 4104
#
# =================================================================
# Total params: 19,257,532
# Trainable params: 14,830,280
# Non-trainable params: 4,427,252
# _________________________________________________________________

# %% [markdown]
# ### Compile and train

# %%
ft_model.compile(
    optimizer=FT_MODEL_OPTIMIZER,
    loss=FT_MODEL_LOSS,
    metrics=['accuracy']
)
ft_model.summary()
# Out:
# Model: "base_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data_augmentation (Sequenti  (None, 96, 96, 3)        0
#  al)
#
#  supernet_preprocessing (Lam  (None, 96, 96, 3)        0
#  bda)
#
#  efficientnetv2-b1 (Function  (None, 3, 3, 1280)       6931124
#  al)
#
#  flatten_13 (Flatten)        (None, 11520)             0
#
#  dropout_13 (Dropout)        (None, 11520)             0
#
#  dense_27 (Dense)            (None, 1024)              11797504
#
#  dense_28 (Dense)            (None, 512)               524800
#
#  output (Dense)              (None, 8)                 4104
#
# =================================================================
# Total params: 19,257,532
# Trainable params: 14,830,280
# Non-trainable params: 4,427,252
# _________________________________________________________________

# %%
if USE_WHOLE_DATASET:
  ft_history = ft_model.fit(
    complete_ds,
    epochs=FT_MODEL_EPOCHS,
    initial_epoch=BASE_MODEL_EPOCHS
  )
else:
  # use early stopping
  ft_max_epochs = 100
  ft_total_epochs =  base_model_early_stopping.best_epoch + ft_max_epochs

  ft_early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=FT_MODEL_EARLY_STOPPING_PATIENCE, restore_best_weights=True)

  ft_history = ft_model.fit(
      train_ds,
      epochs=ft_total_epochs,
      initial_epoch=base_model_early_stopping.best_epoch,
      validation_data=val_ds,
      callbacks = [ft_early_stopping]
  )
# Out:
# Epoch 68/167
# 45/45 [==============================] - 15s 146ms/step - loss: 0.3948 - accuracy: 0.8536 - val_loss: 0.6790 - val_accuracy: 0.7980
# Epoch 69/167
# 45/45 [==============================] - 4s 94ms/step - loss: 0.3377 - accuracy: 0.8825 - val_loss: 0.6947 - val_accuracy: 0.7952
# Epoch 70/167
# 45/45 [==============================] - 4s 96ms/step - loss: 0.3478 - accuracy: 0.8730 - val_loss: 0.6936 - val_accuracy: 0.7994
# Epoch 71/167
# 45/45 [==============================] - 4s 93ms/step - loss: 0.3347 - accuracy: 0.8769 - val_loss: 0.6897 - val_accuracy: 0.7980
# Epoch 72/167
# 45/45 [==============================] - 4s 95ms/step - loss: 0.3324 - accuracy: 0.8888 - val_loss: 0.6464 - val_accuracy: 0.8051
# Epoch 73/167
# 45/45 [==============================] - 4s 93ms/step - loss: 0.3225 - accuracy: 0.8832 - val_loss: 0.6912 - val_accuracy: 0.7938
# 45/45 [==============================] - 4s 93ms/step - loss: 0.2092 - accuracy: 0.9263 - val_loss: 0.6913 - val_accuracy: 0.8107
# Epoch 151/167
# 45/45 [==============================] - 4s 93ms/step - loss: 0.2265 - accuracy: 0.9199 - val_loss: 0.6664 - val_accuracy: 0.8305
# Epoch 152/167
# 45/45 [==============================] - 4s 92ms/step - loss: 0.1984 - accuracy: 0.9326 - val_loss: 0.6885 - val_accuracy: 0.8136
# Epoch 153/167
# 45/45 [==============================] - 4s 92ms/step - loss: 0.1918 - accuracy: 0.9340 - val_loss: 0.6917 - val_accuracy: 0.8192
# Epoch 154/167
# 45/45 [==============================] - 4s 93ms/step - loss: 0.2060 - accuracy: 0.9234 - val_loss: 0.6976 - val_accuracy: 0.8164
# Epoch 155/167
# 45/45 [==============================] - 4s 93ms/step - loss: 0.1947 - accuracy: 0.9351 - val_loss: 0.7115 - val_accuracy: 0.8206
# Epoch 156/167
# 45/45 [==============================] - 4s 96ms/step - loss: 0.1912 - accuracy: 0.9390 - val_loss: 0.6713 - val_accuracy: 0.8263

# %% [markdown]
# ### Visualize results

# %%
acc = ft_history.history['accuracy']
if not USE_WHOLE_DATASET:
  val_acc += ft_history.history['val_accuracy']

loss = ft_history.history['loss']
if not USE_WHOLE_DATASET:
  val_loss += ft_history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
if not USE_WHOLE_DATASET:
  plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([min(plt.ylim()),1])
if not USE_WHOLE_DATASET:
  plt.plot([ft_early_stopping.best_epoch,ft_early_stopping.best_epoch],
         plt.ylim(), label='Best Epoch')
if not USE_WHOLE_DATASET:
  plt.plot([base_model_early_stopping.best_epoch, base_model_early_stopping.best_epoch],
          plt.ylim(), label='Start Fine Tuning')
else:
  plt.plot([BASE_MODEL_EPOCHS, BASE_MODEL_EPOCHS],
          plt.ylim(), label='Start Fine Tuning')

plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
if not USE_WHOLE_DATASET:
  plt.plot(val_loss, label='Validation Loss')
plt.ylim([0,max(plt.ylim())])
if not USE_WHOLE_DATASET:
  plt.plot([ft_early_stopping.best_epoch,ft_early_stopping.best_epoch],
         plt.ylim(), label='Best Epoch')
if not USE_WHOLE_DATASET:
  plt.plot([base_model_early_stopping.best_epoch, base_model_early_stopping.best_epoch],
          plt.ylim(), label='Start Fine Tuning')
else:
  plt.plot([BASE_MODEL_EPOCHS, BASE_MODEL_EPOCHS],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Save model

# %% [markdown]
# Save newly trained fine tuned model

# %%
ft_model_directory = f'models/{base_model_supernet.name}-finetuned-{datetime.today().strftime("%Y-%m-%d-%H-%M-%S")}'
ft_model.save(ft_model_directory)
if IS_COLAB:
  from shutil import make_archive, copyfile
  make_archive(ft_model_directory, 'zip', ft_model_directory)
  copyfile(ft_model_directory + '.zip', COLAB_BASE_DIR + ft_model_directory)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer-0.layer-0._random_generator._generator._state_var
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer-0.layer-1._random_generator._generator._state_var
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer-0.layer-2._random_generator._generator._state_var
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer-0.layer-3._random_generator._generator._state_var
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).layer-0.layer-4._random_generator._generator._state_var
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 91). These functions will not be directly callable after loading.
